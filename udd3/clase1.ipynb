# %% [markdown]
# asd

# %% [markdown]
# ejercicio: calcular el histograma de un punto de interes cde una imagen a colores

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img= cv2.imread('cartman.jpeg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.rcParams['figure.figsize'] = (10, 5)
plt.imshow(img_rgb)
plt.show()

plt.imshow(img_rgb[50:65,20:30,:], cmap='gray')
plt.show()

img_cortada= img_rgb[50:65,20:30,:]
plt.savefig('imagenesGuardadas/cartman_cortado.png', img_cortada)

img_fin=plt.imread('imagenesGuardadas/cartman_cortado.png')
color=('r','g','b')
for canal,col in enumerate(color):
    histograma=cv2.calcHist([img_fin*255],[canal],None,[256],[0,256])
    plt.plot(histograma,color=col)
    plt.xlabel('intensidad')
    plt.ylabel('frecuencia')
    plt.xlim([0,256])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 15
#      12 plt.show()
#      14 img_cortada= img_rgb[50:65,20:30,:]
# ---> 15 plt.savefig('imagenesGuardadas/cartman_cortado.png', img_cortada)
#      17 img_fin=plt.imread('imagenesGuardadas/cartman_cortado.png')
#      18 color=('r','g','b')
#
# File c:\Users\ACER CORE i7\.conda\envs\2pdi2026\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# TypeError: Figure.savefig() takes 2 positional arguments but 3 were given
