# %% [markdown]
# Desarrolle una aplicación que permita introducir 7 números por teclado y determine cual de
# ellos se repite más veces y cuantas.

# %%
try:
    numeros = []
    for i in range(7):
        num = int(input(f"Introduce el número {i+1}: "))
        numeros.append(num)
    
    frecuencias = {}
    for num in numeros:
        if num in frecuencias:
            frecuencias[num] += 1
        else:
            frecuencias[num] = 1
    
    max_repeticiones = 0
    numero_mas_repetido = None
    for num, freq in frecuencias.items():
        if freq > max_repeticiones:
            max_repeticiones = freq
            numero_mas_repetido = num
    
    print(f"Números ingresados: {numeros}")
    print(f"El número que más se repite es: {numero_mas_repetido}")
    print(f"Se repite {max_repeticiones} vez/veces")
except ValueError:
    print("Error: Debes introducir números enteros válidos")
# Out:
# Números ingresados: [77, 77, 55, 48, 89, 77, 1]
# El número que más se repite es: 77
# Se repite 3 vez/veces
